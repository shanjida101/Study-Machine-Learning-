# %% [markdown]
# <a href="https://colab.research.google.com/github/shanjida101/Study-Machine-Learning-/blob/main/learning_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# In Scikit-learn, fetch_california_housing() is a function that downloads and returns the California Housing dataset as a Python object (usually a Bunch, which behaves like a dictionary).

# %%
housing = fetch_california_housing()

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %% [markdown]
# Pandas **Dataframe**

# %%
house_df=pd.DataFrame(housing.data, columns=housing.feature_names)
house_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# (rows,columns)

# %%
house_df.shape
# Out:
# (20640, 8)

# %%
type(house_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Importing data from CSV file to a Pandas Dataframe

# %%
diabetes_df=pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Converting to csv file
# .to_csv('file_path')

# %%
house_df.to_csv('house_df.csv')

# %% [markdown]
# Converting to excel file
# df.to_excel('filename')

# %%
house_df.to_excel('house_df.xlsx')

# %%
#information about dataframe
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# To create a DataFrame with random value

# %%
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.282803  0.900789  0.587196  0.289555  0.653261  0.222097  0.630682
# 1  0.060050  0.995459  0.564103  0.982580  0.124397  0.126796  0.002479
# 2  0.047118  0.853429  0.750136  0.813333  0.423641  0.734029  0.469446
# 3  0.817751  0.486992  0.936318  0.340860  0.703388  0.819247  0.601614
# 4  0.348643  0.822631  0.292867  0.345362  0.351376  0.351130  0.565538
#
#           7         8         9
# 0  0.130311  0.689119  0.483378
# 1  0.827203  0.314694  0.351103
# 2  0.627070  0.298013  0.267963
# 3  0.984180  0.451615  0.897580
# 4  0.105735  0.423191  0.561737

# %% [markdown]
# Statistical Measures

# %%
#to check null values
house_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
#replace the null value with median
house_df.fillna(house_df.median(), inplace=True)

# %%
#show the population more than 5000
house_df[house_df['Population']>5000]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 570    7.6110       5.0  6.855776   1.061442      7427.0  2.732524     37.72
# 576    7.2634      12.0  7.133034   1.018934      5781.0  2.880419     37.77
# 780    3.8171      18.0  5.119733   1.043679      5613.0  2.884378     37.63
# 799    2.5158      22.0  4.006152   1.036227      5436.0  3.715653     37.64
# 864    5.8322      14.0  5.689849   1.051282      8117.0  2.851071     37.57
# ...       ...       ...       ...        ...         ...       ...       ...
# 20529  2.9605      12.0  4.915341   1.022451      5633.0  2.634705     38.55
# 20530  3.1371      11.0  5.070223   1.015530      7984.0  2.695476     38.57
# 20544  2.0650      23.0  4.803493   1.013646      6330.0  3.455240     38.55
# 20563  3.1250       9.0  5.148007   1.119593      6837.0  2.899491     38.67
# 20629  2.0943      28.0  5.519802   1.020902      6912.0  3.801980     39.12
#
#        Longitude  Price
# ...

# %%
house_df.value_counts('Population')
# Out:
# Population
# 891.0     25
# 1052.0    24
# 1227.0    24
# 850.0     24
# 761.0     24
#           ..
# 40.0       1
# 31.0       1
# 3256.0     1
# 1778.0     1
# 3273.0     1
# Name: count, Length: 3888, dtype: int64

# %%
# count or number of values
house_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
house_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc     -0.079809  -0.015176
# HouseAge    0.011173  -0.108197
# AveRooms    0.106389  -0.027540
# AveBedrms   0.069721   0.013344
# Population -0.108785   0.099773
# AveOccup    0.002366   0.002476
# Latitude    1.000000  -0.924664
# Longitude  -0.924664   1.000000

# %%
house_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
#statistical value
house_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
#maximum and minimum value
house_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
house_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
#group the value based on mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Manipulating Dataframe

# %%
# adding a column to a dataframe
house_df['Price'] = housing.target
house_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# removing a row
#axis=0 → rows
#axis=1 → columns

house_df.drop(index=0, axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
house_df.drop(columns='ZN', axis=1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  AveOccup  Latitude  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810  2.555556     37.88    -122.23
# 1      8.3014      21.0  6.238137   0.971880  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136   1.073446  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352   1.073059  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853   1.081081  2.181467     37.85    -122.25
# ...       ...       ...       ...        ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035   1.315789  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543   1.120092  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513   1.171920  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717   1.162264  2.616981     39.37    -121.24
#
#        Price
# 0      4.526
# 1      3.585
# ...

# %%
#row index

house_df.reset_index()
# Out:
#        index  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0          0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1          1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2          2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3          3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4          4  3.8462      52.0  6.281853   1.081081       565.0  2.181467
# ...      ...     ...       ...       ...        ...         ...       ...
# 20635  20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606
# 20636  20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807
# 20637  20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635
# 20638  20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209
# 20639  20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981
#
#        Latitude  Longitude  Price
# 0         37.88    -122.23  4.526
# ...

# %%
#shows 3 rows
house_df.iloc[:3]
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521

# %%
house_df.iloc[:6,3]
# Out:
# 0    1.023810
# 1    0.971880
# 2    1.073446
# 3    1.073059
# 4    1.081081
# 5    1.103627
# Name: AveBedrms, dtype: float64
